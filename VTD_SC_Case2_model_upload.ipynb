# %%
import pandas as pd
import numpy as np
import arviz as az
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors
from scipy.special import expit, logit

import pymc as pm
import bambi as bmb
import pytensor.tensor as pt
import random

import collections.abc
collections.Iterable = collections.abc.Iterable
collections.Mapping = collections.abc.Mapping
collections.MutableSet = collections.abc.MutableSet
collections.MutableMapping = collections.abc.MutableMapping
from causalgraphicalmodels import CausalGraphicalModel
import daft

# %%
# versions

print('\n'.join(f'{m.__name__}=={m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))
# Out:
# pandas==1.5.3
# numpy==1.24.2
# arviz==0.15.1
# seaborn==0.12.2
# pymc==5.1.2
# bambi==0.10.0
# daft==0.1.2

# %%
SEED = 20012808

# %%
# import the data prepared in ERF_get_data_prereg

real_data = pd.read_csv('...')
df2 = real_data.copy()

# limit to taxonomists
real_data = real_data.loc[real_data['taxonomist?'] == 'taxonomist']

# %% [markdown]
# # DAG

# %%
tax_dag_Concept = CausalGraphicalModel(
    nodes=["Species Concept", "Low income",  "Agree", 'Specialization', 'Treatment'], edges=[
        
        ("Species Concept", "Agree"),
        
        ("Low income", "Species Concept"),
        ("Specialization", "Species Concept"),       
        ('Treatment','Agree'),
        ('Specialization','Agree'),
        ('Low income','Agree')
    ]
)


tax_dag_Concept.draw()

# %% [markdown]
# Questions for case 2:
#
# - What is the causal effect of treatment on 'agree'?
# - What is the causal effect of species concept on 'agree'?
# - Does treatment differ between low-income/high income? We expect this because different operationalizations are available differently depending on the budget.
# - How does the influence of concepts compare to that of treatments?

# %%
def independencies(dag):
    all_independencies = dag.get_all_independence_relationships()
    for s in all_independencies:
        if all(
            t[0] != s[0] or t[1] != s[1] or not t[2].issubset(s[2])
            for t in all_independencies
            if t != s
        ):
            print(s)
independencies(tax_dag_Concept)
# Out:
# ('Species Concept', 'Treatment', set())
# ('Treatment', 'Specialization', set())
# ('Treatment', 'Low income', set())
# ('Specialization', 'Low income', set())

# %%
# check which variables to include

# function to check open backdoor paths and, hence, which variables to control for

def backdoor(dag, pred, outcome):
    all_adjustment_sets = dag.get_all_backdoor_adjustment_sets(pred, outcome)
    for s in all_adjustment_sets:
        if all(not t.issubset(s) for t in all_adjustment_sets if t != s):
            print(s)

backdoor(tax_dag_Concept,'Species Concept','Agree')
# Out:
# frozenset({'Low income', 'Specialization'})

# %% [markdown]
# **In the paper, we report on model 7 below, given that it follows most directly from our DAG. This is the model:**
#
# <u>*Likelihood:*</u>
#
# Agree ~ Bernoulli(p)
#
# *Linear model:*
#
# logit(p<sub>i</sub>) = $\alpha$<sub>gen</sub> + $\alpha$1<sub>sc[i]</sub> + $\alpha$2<sub>tax[i]</sub> + $\alpha$3<sub>cont[i]</sub> + $\beta$_treat<sub>treat[i]</sub> + $\beta$_vartreat1<sub>cont[i],treat[i]</sub> + $\beta$_vartreat2<sub>tax[i],treat[i]</sub>
#
#
# <u>*Fixed priors:*</u>
#
# $\alpha$<sub>gen</sub> ~ Normal(0,1)
#
# $\alpha$1_sigma ~ Uniform(0,5)
#
# $\alpha$2_sigma ~ Uniform(0,5)
#
# $\beta$_vartreat1_sigma ~ Uniform(0,5)
#
# $\beta$_vartreat2_sigma ~ Uniform(0,5)
#
# $\beta$_treat<sub>treat</sub> ~ Normal(0,1)
#
# $\alpha$3<sub>cont</sub> ~ Normal(0,1)
#
#
# <u>*Adaptive priors:*</u>
#
# $\alpha$1<sub>sc</sub> ~ Normal(0,$\alpha$1_sigma)
#
# $\alpha$2<sub>tax</sub> ~ Normal(0,$\alpha$2_sigma)
#
# $\beta$_vartreat1<sub>cont,treat</sub> ~ Normal(0,$\beta$_vartreat1_sigma)
#
# $\beta$_vartreat2<sub>tax,treat</sub> ~ Normal(0,$\beta$_vartreat2_sigma)

# %% [markdown]
# # Indices and data
#
# ## Real data

# %%
df = real_data[['c2_agree','condition_c2','specialization','low_income','species_concepts']].copy()
df.columns = ['agree','t','tax','cont','sc']
df = df.dropna()
df = df[~df.apply(lambda row: row.astype(str).str.contains('No response', case=False).any(), axis=1)]
df = df.astype('category')
df
# Out:
#     agree           t                    tax cont       sc
# 0     yes     Habitat  Non-insect Arthropods    0      BSC
# 1     yes  Morphology                Insects    0      ESC
# 2      no     Neutral  Non-insect Arthropods    0      BSC
# 3      no     Neutral                 Plants    0   diaPSC
# 4     yes         DNA                 Plants    0   diaPSC
# ..    ...         ...                    ...  ...      ...
# 566   yes     Habitat                Mammals    1   diaPSC
# 568    no     Neutral                Insects    1   diaPSC
# 570    no     Neutral                Insects    0      ESC
# 572    no     Habitat  Non-insect Arthropods    1  monoPSC
# 573   yes         DNA                Mammals    1      ESC
#
# [423 rows x 5 columns]

# %% [markdown]
# ## coordinates for the models

# %%
#  Index of positions
t_idx = df.t.cat.codes.values
sc_idx = df.sc.cat.codes.values
agree_idx = df.agree.cat.codes.values
tax_idx = df.tax.cat.codes.values
cont_idx = df.cont.cat.codes.values



# The 9 position names
t_codes = df.t.cat.categories.values
sc_codes = df.sc.cat.categories.values
tax_codes = df.tax.cat.categories.values
cont_codes = df.cont.cat.categories.values



coords = {'t_n': t_codes,  'sc_n':sc_codes, 'tax_n':tax_codes, 'c_n':cont_codes, 'agree_codes':agree_idx}

# %% [markdown]
# # Model 1: simple regression Treatment --> Agree

# %%
with pm.Model(coords = coords) as m1:
    
    # data
    T = pm.MutableData('T', df.t.cat.codes.values)
    
    # priors
    a_t = pm.Normal('a_t',0,1,dims = 't_n')
    a = pm.Normal('a',0,1)
    
    # linear model
    p = pm.math.invlogit(a + a_t[T])
    
    agree = pm.Bernoulli('agree',p=p, observed = df.agree.cat.codes.values)
    
    tracem1 = pm.sample(10000,idata_kwargs={"log_likelihood": True})
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a_t, a]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='44000' class='' max='44000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44000/44000 00:40&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 10_000 draw iterations (4_000 + 40_000 draws total) took 62 seconds.

# %%
az.summary(tracem1)
# Out:
#                   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# a_t[DNA]         1.123  0.504   0.190    2.079      0.005    0.004    8965.0
# a_t[Habitat]     0.331  0.484  -0.563    1.267      0.005    0.004    8023.0
# a_t[Morphology] -0.126  0.482  -1.029    0.791      0.005    0.004    8156.0
# a_t[Neutral]    -0.754  0.478  -1.643    0.160      0.005    0.004    7957.0
# a                0.605  0.456  -0.276    1.447      0.005    0.004    7425.0
#
#                  ess_tail  r_hat
# a_t[DNA]          12142.0    1.0
# a_t[Habitat]      10776.0    1.0
# a_t[Morphology]   10636.0    1.0
# a_t[Neutral]      10706.0    1.0
# a                  9418.0    1.0

# %% [markdown]
# # Model 2: Add species concept

# %%
with pm.Model(coords = coords) as m2:
    # data
    S = pm.MutableData('S', df.sc.cat.codes.values)
    T = pm.MutableData('T', df.t.cat.codes.values)
    
    # priors
    a_sc = pm.Normal('a_sc',0,1,dims = 'sc_n')
    t = pm.Normal('t',0,1,dims = 't_n')
    a = pm.Normal('a',0,1)
    
    # linear model
    p = pm.math.invlogit(a + a_sc[S] + t[T])
    
    agree = pm.Bernoulli('agree',p=p, observed = df.agree.cat.codes.values)
    
    tracem2 = pm.sample(10000,idata_kwargs={"log_likelihood": True})
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a_sc, t, a]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='44000' class='' max='44000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44000/44000 01:04&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 10_000 draw iterations (4_000 + 40_000 draws total) took 92 seconds.

# %%
az.summary(tracem2)
# Out:
#                 mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# a_sc[BSC]      0.184  0.442  -0.645    1.011      0.004    0.003   12781.0
# a_sc[ESC]      0.188  0.443  -0.648    1.015      0.004    0.003   13129.0
# a_sc[GCSC]    -0.145  0.610  -1.292    1.006      0.004    0.003   19534.0
# a_sc[diaPSC]   0.220  0.441  -0.612    1.043      0.004    0.003   12787.0
# a_sc[monoPSC]  0.337  0.490  -0.588    1.250      0.004    0.003   14991.0
# a_sc[other]   -0.242  0.482  -1.124    0.680      0.004    0.003   14692.0
# t[DNA]         1.107  0.507   0.148    2.065      0.005    0.003   12341.0
# t[Habitat]     0.308  0.488  -0.601    1.233      0.005    0.003   11621.0
# t[Morphology] -0.143  0.485  -1.078    0.751      0.005    0.003   11494.0
# t[Neutral]    -0.799  0.483  -1.689    0.123      0.005    0.003   11204.0
# a              0.485  0.549  -0.516    1.557      0.005    0.004   11106.0
#
#                ess_tail  r_hat
# a_sc[BSC]       19254.0    1.0
# a_sc[ESC]       19395.0    1.0
# a_sc[GCSC]      23417.0    1.0
# a_sc[diaPSC]    18936.0    1.0
# a_sc[monoPSC]   21604.0    1.0
# a_sc[other]     20895.0    1.0
# t[DNA]          17536.0    1.0
# t[Habitat]      17023.0    1.0
# t[Morphology]   16810.0    1.0
# t[Neutral]      16212.0    1.0
# a               15165.0    1.0

# %% [markdown]
# # Model 3: Add controls for tax and cont
#
# This is necessary to get the causal effect of species concepts

# %%
with pm.Model(coords=coords) as m3:
    
    # data
    S = pm.MutableData('S', df.sc.cat.codes.values)
    T = pm.MutableData('T', df.t.cat.codes.values)
    TA = pm.MutableData('TA', df.tax.cat.codes.values)
    C = pm.MutableData('C', df.cont.cat.codes.values)
    
    # priors
    a = pm.Normal('a',0,1)
    a_sc = pm.Normal('a_sc',0,1,dims = 'sc_n')
    b1 = pm.Normal('b1',0,1,dims = 't_n')
    b2 = pm.Normal('b2',0,1,dims = 'tax_n')
    b3 = pm.Normal('b3',0,1)
    
    # linear model
    p = a + a_sc[S] + b1[T] + b2[TA] + b3*C
    
    agree = pm.Bernoulli('agree',logit_p=p, observed = df.agree.cat.codes.values)
    pr3 = pm.sample_prior_predictive()
# Out:
# Sampling: [a, a_sc, agree, b1, b2, b3]

# %%
with m3:
    tracem3 = pm.sample(10000,idata_kwargs={"log_likelihood": True})
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a, a_sc, b1, b2, b3]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='44000' class='' max='44000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44000/44000 01:46&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 10_000 draw iterations (4_000 + 40_000 draws total) took 125 seconds.

# %%
az.summary(tracem3).head()
# Out:
#                mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# a             0.379  0.589  -0.728    1.482      0.005    0.004   13271.0
# a_sc[BSC]     0.140  0.444  -0.701    0.959      0.004    0.003   13902.0
# a_sc[ESC]     0.222  0.442  -0.594    1.070      0.004    0.003   14044.0
# a_sc[GCSC]   -0.183  0.608  -1.326    0.962      0.003    0.003   32300.0
# a_sc[diaPSC]  0.175  0.440  -0.663    1.000      0.004    0.003   14507.0
#
#               ess_tail  r_hat
# a              19529.0    1.0
# a_sc[BSC]      24456.0    1.0
# a_sc[ESC]      23178.0    1.0
# a_sc[GCSC]     28910.0    1.0
# a_sc[diaPSC]   23727.0    1.0

# %% [markdown]
# # multilevel models
#
# We see no reason why treatment would vary by anything but income, or perhaps taxon, so that's all we model.

# %% [markdown]
# ## Model 4: Treatment  + sc

# %%
with pm.Model(coords=coords) as m4:
    
    # data
    S = pm.MutableData('S', df.sc.cat.codes.values)
    T = pm.MutableData('T', df.t.cat.codes.values)
    
    # fixed priors
    a_gen = pm.Normal('a_gen',0,1)
    a1_sigma = pm.Uniform('a1_sigma',0.01,10)
    b_t = pm.Normal('b_t',0,2, dims = 't_n')
    
    # adaptive priors
    z1 = pm.Normal('z1',0,1, dims = 'sc_n')
    a1 = pm.Deterministic("a1",z1*a1_sigma)
    
    p = (a_gen + a1[S]  + b_t[T])
    
    agree = pm.Bernoulli('agree',logit_p=p, observed = df.agree.cat.codes.values)
    
    pr4 = pm.sample_prior_predictive()
# Out:
# Sampling: [a1_sigma, a_gen, agree, b_t, z1]

# %%
with m4: 
    tracem4 = pm.sample(10000, tune = 3000,idata_kwargs={"log_likelihood": True}, target_accept = 0.95)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a_gen, a1_sigma, b_t, z1]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='52000' class='' max='52000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [52000/52000 02:43&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 3_000 tune and 10_000 draw iterations (12_000 + 40_000 draws total) took 186 seconds.

# %%
az.summary(tracem4).head()
# Out:
#                   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# a_gen            0.381  0.709  -0.939    1.715      0.008    0.006    7959.0
# b_t[DNA]         1.392  0.749  -0.023    2.781      0.008    0.006    8572.0
# b_t[Habitat]     0.544  0.731  -0.837    1.895      0.008    0.006    8203.0
# b_t[Morphology]  0.076  0.730  -1.266    1.481      0.008    0.006    8143.0
# b_t[Neutral]    -0.576  0.726  -1.972    0.753      0.008    0.006    8035.0
#
#                  ess_tail  r_hat
# a_gen             13172.0    1.0
# b_t[DNA]          15264.0    1.0
# b_t[Habitat]      14392.0    1.0
# b_t[Morphology]   14830.0    1.0
# b_t[Neutral]      14381.0    1.0

# %% [markdown]
# ## Model 5: add continent and varying effects for continent

# %%
with pm.Model(coords=coords) as m5:
    
    # data
    S = pm.MutableData('S', df.sc.cat.codes.values)
    T = pm.MutableData('T', df.t.cat.codes.values)
    C = pm.MutableData('C',df.cont.cat.codes.values)
    
    # fixed priors
    a_gen = pm.Normal('a_gen',0,1)
    a1_sigma = pm.Uniform('a1_sigma',0.01,10)
    b_t = pm.Normal('b_t',0,2, dims = 't_n')
    b_ct_sigma = pm.Uniform('b_ct_sigma',0.01,10)
    a_cont = pm.Normal('a_cont',0,1)

    
    # adaptive priors
    z1 = pm.Normal('z1',0,1, dims = 'sc_n')
    z3 = pm.Normal('z3',0,1, dims = ('t_n'))
    a1 = pm.Deterministic("a1",z1*a1_sigma)
    b_ct = pm.Deterministic("b_ct", z3*b_ct_sigma)
    
    p = (a_gen + a1[S]  + b_t[T] + a_cont*C + b_ct[T]*C )
    
    agree = pm.Bernoulli('agree',logit_p=p, observed = df.agree.cat.codes.values)
    
    pr5 = pm.sample_prior_predictive()
# Out:
# Sampling: [a1_sigma, a_cont, a_gen, agree, b_ct_sigma, b_t, z1, z3]

# %%
# check priors

fig, axs = plt.subplots(2,3, figsize = (20,6))

for ax, para in zip(axs.flat, ['a_gen', 'a1','a1_sigma','b_ct','b_ct_sigma','b_t']):
    if len(pr5.prior[para].shape) == 3:
        az.plot_posterior(pr5.prior[para][:,:,0], ax=ax)
    elif len(pr5.prior[para].shape) == 2:
        az.plot_posterior(pr5.prior[para],ax=ax)
    else:
        az.plot_posterior(pr5.prior[para][:,:,1,0],ax=ax)
plt.suptitle('priors', fontsize = 20) 

plt.show()
fig.tight_layout()

# %%
with m5: 
    tracem5 = pm.sample(10000, tune = 3000, target_accept = 0.95,idata_kwargs={"log_likelihood": True})
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a_gen, a1_sigma, b_t, b_ct_sigma, a_cont, z1, z3]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='52000' class='' max='52000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [52000/52000 04:50&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 3_000 tune and 10_000 draw iterations (12_000 + 40_000 draws total) took 314 seconds.

# %%
az.summary(tracem5).head()
# Out:
#                   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# a_gen            0.351  0.720  -0.977    1.732      0.007    0.005   11597.0
# b_t[DNA]         1.383  0.770  -0.100    2.790      0.007    0.005   12413.0
# b_t[Habitat]     0.582  0.747  -0.831    1.977      0.007    0.005   11906.0
# b_t[Morphology] -0.021  0.750  -1.450    1.365      0.007    0.005   11942.0
# b_t[Neutral]    -0.540  0.743  -1.941    0.855      0.007    0.005   11979.0
#
#                  ess_tail  r_hat
# a_gen             16813.0    1.0
# b_t[DNA]          18008.0    1.0
# b_t[Habitat]      17525.0    1.0
# b_t[Morphology]   18533.0    1.0
# b_t[Neutral]      17682.0    1.0

# %% [markdown]
# ## Model 6: Add taxon

# %%
with pm.Model(coords=coords) as m6:
    
    # data
    S = pm.MutableData('S', df.sc.cat.codes.values)
    T = pm.MutableData('T', df.t.cat.codes.values)
    C = pm.MutableData('C',df.cont.cat.codes.values)
    TA = pm.MutableData('TA',df.tax.cat.codes.values)
    
    # fixed priors
    a_gen = pm.Normal('a_gen',0,1)
    a1_sigma = pm.Uniform('a1_sigma',0,5)
    b_t = pm.Normal('b_t',0,2, dims = 't_n')
    b_ct_sigma = pm.Uniform('b_ct_sigma',0,5)
    a_cont = pm.Normal('a_cont',0,1)
    a_tax_sigma = pm.Uniform('a_tax_sigma',0,5)

    
    # adaptive priors
    z1 = pm.Normal('z1',0,1, dims = 'sc_n')
    z3 = pm.Normal('z3',0,1, dims = ('t_n'))
    a1 = pm.Deterministic("a1",z1*a1_sigma)
    b_ct = pm.Deterministic("b_ct", z3*b_ct_sigma)
    z2 = pm.Normal('z2',0,1, dims = 'tax_n')
    a_tax = pm.Deterministic("a_tax",z2*a_tax_sigma, dims = 'tax_n')
    
    # linear model
    p = (a_gen + a1[S]  + b_t[T] + a_cont*C + b_ct[T]*C + a_tax[TA])
    
    agree = pm.Bernoulli('agree',logit_p=p, observed = df.agree.cat.codes.values)
    
    pr6 = pm.sample_prior_predictive()
# Out:
# Sampling: [a1_sigma, a_cont, a_gen, a_tax_sigma, agree, b_ct_sigma, b_t, z1, z2, z3]

# %%
with m6: 
    tracem6 = pm.sample(10000, tune = 3000, target_accept = 0.95,idata_kwargs={"log_likelihood": True})
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a_gen, a1_sigma, b_t, b_ct_sigma, a_cont, a_tax_sigma, z1, z3, z2]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='52000' class='' max='52000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [52000/52000 06:01&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 3_000 tune and 10_000 draw iterations (12_000 + 40_000 draws total) took 388 seconds.

# %%
az.summary(tracem6).head()
# Out:
#                   mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# a_gen            0.323  0.708  -0.991    1.678      0.007    0.005    9433.0
# b_t[DNA]         1.397  0.754   0.001    2.834      0.008    0.005    9985.0
# b_t[Habitat]     0.590  0.738  -0.769    2.010      0.007    0.005    9715.0
# b_t[Morphology] -0.069  0.737  -1.474    1.308      0.008    0.005    9627.0
# b_t[Neutral]    -0.571  0.731  -1.937    0.808      0.008    0.005    9491.0
#
#                  ess_tail  r_hat
# a_gen             16400.0    1.0
# b_t[DNA]          17659.0    1.0
# b_t[Habitat]      16870.0    1.0
# b_t[Morphology]   17427.0    1.0
# b_t[Neutral]      16741.0    1.0

# %% [markdown]
# ## Model 7: Vary treatment by taxon
#
# <u>*Likelihood:*</u>
#
# Agree ~ Bernoulli(p)
#
# *Linear model:*
#
# logit(p<sub>i</sub>) = $\alpha$<sub>gen</sub> + $\alpha$1<sub>sc[i]</sub> + $\alpha$2<sub>tax[i]</sub> + $\alpha$3<sub>cont[i]</sub> + $\beta$_treat<sub>treat[i]</sub> + $\beta$_vartreat1<sub>cont[i],treat[i]</sub> + $\beta$_vartreat2<sub>tax[i],treat[i]</sub>
#
#
# <u>*Fixed priors:*</u>
#
# $\alpha$<sub>gen</sub> ~ Normal(0,1)
#
# $\alpha$1_sigma ~ Uniform(0,5)
#
# $\alpha$2_sigma ~ Uniform(0,5)
#
# $\beta$_vartreat1_sigma ~ Uniform(0,5)
#
# $\beta$_vartreat2_sigma ~ Uniform(0,5)
#
# $\beta$_treat<sub>treat</sub> ~ Normal(0,1)
#
# $\alpha$3<sub>cont</sub> ~ Normal(0,1)
#
#
# <u>*Adaptive priors:*</u>
#
# $\alpha$1<sub>sc</sub> ~ Normal(0,$\alpha$1_sigma)
#
# $\alpha$2<sub>tax</sub> ~ Normal(0,$\alpha$2_sigma)
#
# $\beta$_vartreat1<sub>cont,treat</sub> ~ Normal(0,$\beta$_vartreat1_sigma)
#
# $\beta$_vartreat2<sub>tax,treat</sub> ~ Normal(0,$\beta$_vartreat2_sigma)

# %%
with pm.Model(coords=coords) as m7:
    
    # data
    S = pm.MutableData('S', df.sc.cat.codes.values)
    T = pm.MutableData('T', df.t.cat.codes.values)
    C = pm.MutableData('C',df.cont.cat.codes.values)
    TA = pm.MutableData('TA',df.tax.cat.codes.values)
    
    # fixed priors
    a_gen = pm.Normal('a_gen',0,1)
    a1_sigma = pm.Uniform('a1_sigma',0,5) # hyper sc
    b_treat = pm.Normal('b_treat',0,2, dims = 't_n')
    b_vartreat1_sigma = pm.Uniform('b_vartreat1_sigma',0,5) # hyper varying effects continent
    b_vartreat2_sigma = pm.Uniform('b_vartreat2_sigma',0,5) # hyper varying effects taxon
    a3 = pm.Normal('a3',0,1, dims = 'c_n')
    a2_sigma = pm.Uniform('a2_sigma',0,5) # hyper taxon

    
    # adaptive priors (non centered)
    z1 = pm.Normal('z1',0,1, dims = 'sc_n')
    z3 = pm.Normal('z3',0,1, dims = ('c_n','t_n'))
    a1 = pm.Deterministic("a1",z1*a1_sigma, dims = 'sc_n')
    b_vartreat1 = pm.Deterministic("b_vartreat1", z3*b_vartreat1_sigma, dims = ('c_n','t_n'))
    z2 = pm.Normal('z2',0,1, dims = 'tax_n')
    a2 = pm.Deterministic("a2",z2*a2_sigma, dims = 'tax_n')
    z4 = pm.Normal('z4',0,1, dims = ('tax_n','t_n'))
    b_vartreat2 = pm.Deterministic('b_vartreat2',z4*b_vartreat1_sigma, dims = ('tax_n','t_n'))
    
    # linear model
    p = (a_gen + a1[S] + a2[TA] + a3[C] + b_treat[T]  + b_vartreat1[C,T]  + b_vartreat2[TA,T])
    
    agree = pm.Bernoulli('agree',logit_p=p, observed = df.agree.cat.codes.values)
    
    pr7 = pm.sample_prior_predictive()
# Out:
# Sampling: [a1_sigma, a2_sigma, a3, a_gen, agree, b_treat, b_vartreat1_sigma, b_vartreat2_sigma, z1, z2, z3, z4]

# %%
with m7: 
    tracem7 = pm.sample(10000, tune = 3000, target_accept = 0.95,idata_kwargs={"log_likelihood": True})
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a_gen, a1_sigma, b_treat, b_vartreat1_sigma, b_vartreat2_sigma, a3, a2_sigma, z1, z3, z2, z4]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='52000' class='' max='52000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [52000/52000 11:36&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 3_000 tune and 10_000 draw iterations (12_000 + 40_000 draws total) took 719 seconds.

# %%
az.summary(tracem7).head()
# Out:
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# a_gen                0.297  0.785  -1.119    1.834      0.004    0.004
# b_treat[DNA]         1.409  0.854  -0.234    2.978      0.005    0.004
# b_treat[Habitat]     0.412  0.840  -1.140    2.015      0.005    0.004
# b_treat[Morphology]  0.005  0.835  -1.551    1.586      0.005    0.004
# b_treat[Neutral]    -0.641  0.831  -2.202    0.919      0.005    0.004
#
#                      ess_bulk  ess_tail  r_hat
# a_gen                 39526.0   29130.0    1.0
# b_treat[DNA]          25769.0   28932.0    1.0
# b_treat[Habitat]      24842.0   28600.0    1.0
# b_treat[Morphology]   24316.0   29193.0    1.0
# b_treat[Neutral]      24484.0   29057.0    1.0

# %% [markdown]
# # Compare models

# %% [markdown]
# Note that this just checks the in and out of sample fit of the models -- no causal conclusions can be drawn from this.

# %%
models = {'only t':tracem1, 't+sc':tracem2,'t+sc+tax+c':tracem3,'ml t+sc':tracem4, 'ml t+sc+c':tracem5,'ml t+sc+c+tax':tracem6,'ml t+sc+c+tax_ve':tracem7}

a = az.compare(models)
a
# Out:
#                   rank    elpd_loo      p_loo  elpd_diff        weight  \
# only t               0 -255.482900   3.871428   0.000000  9.068130e-01
# ml t+sc              1 -256.584528   5.570235   1.101628  8.220986e-14
# ml t+sc+c+tax_ve     2 -257.773123  17.447720   2.290223  6.425146e-14
# ml t+sc+c            3 -258.210390   8.074045   2.727490  8.666776e-14
# ml t+sc+c+tax        4 -258.213250  12.752993   2.730350  7.387264e-14
# t+sc                 5 -258.835603   8.475657   3.352703  8.736644e-14
# t+sc+tax+c           6 -261.812333  19.330513   6.329433  9.318700e-02
#
#                         se       dse  warning scale
# only t            8.219428  0.000000    False   log
# ml t+sc           8.474458  0.506106    False   log
# ml t+sc+c+tax_ve  8.758220  2.288329    False   log
# ml t+sc+c         8.621168  1.119846    False   log
# ml t+sc+c+tax     8.710494  1.978295    False   log
# t+sc              8.515176  1.494978    False   log
# t+sc+tax+c        9.318772  4.011561    False   log

# %%
az.plot_compare(a, insample_dev = True)
# Out:
# <Axes: title={'center': 'Model comparison\nhigher is better'}, xlabel='elpd_loo (log)', ylabel='ranked models'>

# %% [markdown]
# # Results and interpretation

# %% [markdown]
# ## General

# %%
az.summary(tracem7, var_names = ['a_gen','a1','b_treat'])
# Out:
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# a_gen                0.297  0.785  -1.119    1.834      0.004    0.004
# a1[BSC]              0.030  0.176  -0.303    0.392      0.001    0.001
# a1[ESC]              0.039  0.177  -0.267    0.427      0.001    0.001
# a1[GCSC]            -0.037  0.230  -0.529    0.386      0.001    0.001
# a1[diaPSC]           0.033  0.174  -0.274    0.409      0.001    0.001
# a1[monoPSC]          0.057  0.204  -0.294    0.504      0.001    0.001
# a1[other]           -0.100  0.215  -0.569    0.240      0.001    0.001
# b_treat[DNA]         1.409  0.854  -0.234    2.978      0.005    0.004
# b_treat[Habitat]     0.412  0.840  -1.140    2.015      0.005    0.004
# b_treat[Morphology]  0.005  0.835  -1.551    1.586      0.005    0.004
# b_treat[Neutral]    -0.641  0.831  -2.202    0.919      0.005    0.004
#
#                      ess_bulk  ess_tail  r_hat
# a_gen                 39526.0   29130.0    1.0
# a1[BSC]               57128.0   35876.0    1.0
# a1[ESC]               60139.0   33849.0    1.0
# a1[GCSC]              62303.0   33581.0    1.0
# a1[diaPSC]            57304.0   36608.0    1.0
# a1[monoPSC]           55179.0   35303.0    1.0
# a1[other]             46699.0   35034.0    1.0
# b_treat[DNA]          25769.0   28932.0    1.0
# b_treat[Habitat]      24842.0   28600.0    1.0
# b_treat[Morphology]   24316.0   29193.0    1.0
# b_treat[Neutral]      24484.0   29057.0    1.0

# %%
az.summary(tracem7, var_names = ['b_vartreat1'])
# Out:
#                              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# b_vartreat1[0, DNA]        -0.010  0.315  -0.656    0.606      0.001    0.002
# b_vartreat1[0, Habitat]     0.088  0.312  -0.472    0.774      0.001    0.001
# b_vartreat1[0, Morphology] -0.115  0.310  -0.767    0.456      0.001    0.001
# b_vartreat1[0, Neutral]     0.047  0.304  -0.534    0.682      0.001    0.001
# b_vartreat1[1, DNA]         0.055  0.318  -0.546    0.724      0.001    0.002
# b_vartreat1[1, Habitat]    -0.080  0.312  -0.766    0.482      0.001    0.002
# b_vartreat1[1, Morphology]  0.115  0.311  -0.460    0.772      0.001    0.001
# b_vartreat1[1, Neutral]    -0.067  0.305  -0.711    0.508      0.001    0.001
#
#                             ess_bulk  ess_tail  r_hat
# b_vartreat1[0, DNA]          68683.0   33013.0    1.0
# b_vartreat1[0, Habitat]      56106.0   30303.0    1.0
# b_vartreat1[0, Morphology]   53791.0   31312.0    1.0
# b_vartreat1[0, Neutral]      64141.0   32039.0    1.0
# b_vartreat1[1, DNA]          62034.0   31893.0    1.0
# b_vartreat1[1, Habitat]      58521.0   30934.0    1.0
# b_vartreat1[1, Morphology]   56745.0   30679.0    1.0
# b_vartreat1[1, Neutral]      60871.0   31895.0    1.0

# %%
az.summary(tracem7, var_names = ['b_vartreat2'])
# Out:
#                                                      mean     sd  hdi_3%  \
# b_vartreat2[Algae, DNA]                             0.023  0.351  -0.668
# b_vartreat2[Algae, Habitat]                         0.037  0.344  -0.630
# b_vartreat2[Algae, Morphology]                     -0.061  0.344  -0.785
# b_vartreat2[Algae, Neutral]                        -0.137  0.358  -0.900
# b_vartreat2[Birds, DNA]                             0.035  0.346  -0.647
# b_vartreat2[Birds, Habitat]                        -0.082  0.348  -0.836
# b_vartreat2[Birds, Morphology]                      0.089  0.344  -0.553
# b_vartreat2[Birds, Neutral]                         0.059  0.324  -0.555
# b_vartreat2[Fish, DNA]                             -0.081  0.329  -0.781
# b_vartreat2[Fish, Habitat]                          0.010  0.327  -0.643
# b_vartreat2[Fish, Morphology]                       0.052  0.317  -0.576
# b_vartreat2[Fish, Neutral]                          0.262  0.382  -0.300
# b_vartreat2[Fungi, DNA]                            -0.001  0.351  -0.698
# b_vartreat2[Fungi, Habitat]                        -0.042  0.337  -0.748
# b_vartreat2[Fungi, Morphology]                     -0.065  0.352  -0.788
# b_vartreat2[Fungi, Neutral]                         0.120  0.359  -0.532
# b_vartreat2[Insects, DNA]                           0.107  0.314  -0.469
# b_vartreat2[Insects, Habitat]                       0.292  0.352  -0.239
# b_vartreat2[Insects, Morphology]                   -0.064  0.267  -0.615
# b_vartreat2[Insects, Neutral]                      -0.114  0.274  -0.686
# b_vartreat2[Mammals, DNA]                           0.021  0.321  -0.608
# b_vartreat2[Mammals, Habitat]                       0.061  0.330  -0.571
# b_vartreat2[Mammals, Morphology]                   -0.112  0.326  -0.821
# b_vartreat2[Mammals, Neutral]                      -0.039  0.301  -0.665
# b_vartreat2[Molluscs, DNA]                          0.067  0.337  -0.544
# b_vartreat2[Molluscs, Habitat]                     -0.045  0.322  -0.723
# b_vartreat2[Molluscs, Morphology]                   0.011  0.326  -0.660
# b_vartreat2[Molluscs, Neutral]                     -0.024  0.313  -0.635
# b_vartreat2[Non-insect Arthropods, DNA]            -0.228  0.363  -1.015
# b_vartreat2[Non-insect Arthropods, Habitat]        -0.016  0.287  -0.595
# b_vartreat2[Non-insect Arthropods, Morphology]      0.072  0.304  -0.484
# b_vartreat2[Non-insect Arthropods, Neutral]        -0.130  0.314  -0.793
# b_vartreat2[Non-vertebrate Deuterostomes, DNA]      0.000  0.354  -0.724
# b_vartreat2[Non-vertebrate Deuterostomes, Habitat]  0.071  0.350  -0.603
# b_vartreat2[Non-vertebrate Deuterostomes, Morph...  0.051  0.347  -0.611
# b_vartreat2[Non-vertebrate Deuterostomes, Neutral] -0.056  0.344  -0.766
# b_vartreat2[Plants, DNA]                            0.092  0.324  -0.500
# b_vartreat2[Plants, Habitat]                       -0.152  0.320  -0.845
# b_vartreat2[Plants, Morphology]                     0.243  0.351  -0.289
# b_vartreat2[Plants, Neutral]                       -0.054  0.287  -0.657
# b_vartreat2[Prokaryotes, DNA]                       0.020  0.347  -0.667
# b_vartreat2[Prokaryotes, Habitat]                  -0.075  0.351  -0.803
# b_vartreat2[Prokaryotes, Morphology]               -0.001  0.352  -0.676
# b_vartreat2[Prokaryotes, Neutral]                   0.001  0.354  -0.724
# b_vartreat2[Protists (non-algae), DNA]              0.001  0.350  -0.719
# b_vartreat2[Protists (non-algae), Habitat]          0.004  0.330  -0.646
# b_vartreat2[Protists (non-algae), Morphology]      -0.022  0.338  -0.713
# b_vartreat2[Protists (non-algae), Neutral]         -0.053  0.348  -0.778
# b_vartreat2[Remaining invertebrates, DNA]           0.112  0.341  -0.484
# b_vartreat2[Remaining invertebrates, Habitat]      -0.038  0.309  -0.667
# b_vartreat2[Remaining invertebrates, Morphology]   -0.006  0.301  -0.622
# b_vartreat2[Remaining invertebrates, Neutral]       0.116  0.303  -0.447
# b_vartreat2[Reptiles and Amphibia, DNA]            -0.125  0.335  -0.842
# b_vartreat2[Reptiles and Amphibia, Habitat]        -0.015  0.311  -0.649
# b_vartreat2[Reptiles and Amphibia, Morphology]     -0.185  0.364  -0.947
# b_vartreat2[Reptiles and Amphibia, Neutral]         0.031  0.299  -0.550
#
#                                                     hdi_97%  mcse_mean  \
# b_vartreat2[Algae, DNA]                               0.747      0.001
# b_vartreat2[Algae, Habitat]                           0.750      0.001
# b_vartreat2[Algae, Morphology]                        0.599      0.001
# b_vartreat2[Algae, Neutral]                           0.490      0.002
# b_vartreat2[Birds, DNA]                               0.740      0.001
# b_vartreat2[Birds, Habitat]                           0.544      0.001
# b_vartreat2[Birds, Morphology]                        0.807      0.001
# b_vartreat2[Birds, Neutral]                           0.743      0.001
# b_vartreat2[Fish, DNA]                                0.530      0.001
# b_vartreat2[Fish, Habitat]                            0.673      0.001
# b_vartreat2[Fish, Morphology]                         0.694      0.001
# b_vartreat2[Fish, Neutral]                            1.078      0.002
# b_vartreat2[Fungi, DNA]                               0.708      0.001
# b_vartreat2[Fungi, Habitat]                           0.611      0.001
# b_vartreat2[Fungi, Morphology]                        0.612      0.001
# b_vartreat2[Fungi, Neutral]                           0.874      0.002
# b_vartreat2[Insects, DNA]                             0.767      0.001
# b_vartreat2[Insects, Habitat]                         1.010      0.002
# b_vartreat2[Insects, Morphology]                      0.443      0.001
# b_vartreat2[Insects, Neutral]                         0.380      0.001
# b_vartreat2[Mammals, DNA]                             0.688      0.001
# b_vartreat2[Mammals, Habitat]                         0.735      0.001
# b_vartreat2[Mammals, Morphology]                      0.461      0.001
# b_vartreat2[Mammals, Neutral]                         0.556      0.001
# b_vartreat2[Molluscs, DNA]                            0.808      0.001
# b_vartreat2[Molluscs, Habitat]                        0.576      0.001
# b_vartreat2[Molluscs, Morphology]                     0.656      0.001
# b_vartreat2[Molluscs, Neutral]                        0.626      0.001
# b_vartreat2[Non-insect Arthropods, DNA]               0.326      0.002
# b_vartreat2[Non-insect Arthropods, Habitat]           0.561      0.001
# b_vartreat2[Non-insect Arthropods, Morphology]        0.731      0.001
# b_vartreat2[Non-insect Arthropods, Neutral]           0.426      0.002
# b_vartreat2[Non-vertebrate Deuterostomes, DNA]        0.695      0.001
# b_vartreat2[Non-vertebrate Deuterostomes, Habitat]    0.782      0.001
# b_vartreat2[Non-vertebrate Deuterostomes, Morph...    0.788      0.001
# b_vartreat2[Non-vertebrate Deuterostomes, Neutral]    0.607      0.001
# b_vartreat2[Plants, DNA]                              0.770      0.001
# b_vartreat2[Plants, Habitat]                          0.392      0.001
# b_vartreat2[Plants, Morphology]                       0.981      0.002
# b_vartreat2[Plants, Neutral]                          0.496      0.001
# b_vartreat2[Prokaryotes, DNA]                         0.723      0.001
# b_vartreat2[Prokaryotes, Habitat]                     0.594      0.001
# b_vartreat2[Prokaryotes, Morphology]                  0.742      0.001
# b_vartreat2[Prokaryotes, Neutral]                     0.709      0.001
# b_vartreat2[Protists (non-algae), DNA]                0.698      0.001
# b_vartreat2[Protists (non-algae), Habitat]            0.682      0.001
# b_vartreat2[Protists (non-algae), Morphology]         0.645      0.001
# b_vartreat2[Protists (non-algae), Neutral]            0.605      0.001
# b_vartreat2[Remaining invertebrates, DNA]             0.849      0.002
# b_vartreat2[Remaining invertebrates, Habitat]         0.571      0.001
# b_vartreat2[Remaining invertebrates, Morphology]      0.585      0.001
# b_vartreat2[Remaining invertebrates, Neutral]         0.744      0.001
# b_vartreat2[Reptiles and Amphibia, DNA]               0.463      0.002
# b_vartreat2[Reptiles and Amphibia, Habitat]           0.599      0.001
# b_vartreat2[Reptiles and Amphibia, Morphology]        0.428      0.002
# b_vartreat2[Reptiles and Amphibia, Neutral]           0.659      0.001
#
#                                                     mcse_sd  ess_bulk  \
# b_vartreat2[Algae, DNA]                               0.002   77404.0
# b_vartreat2[Algae, Habitat]                           0.002   72023.0
# b_vartreat2[Algae, Morphology]                        0.002   69064.0
# b_vartreat2[Algae, Neutral]                           0.002   48987.0
# b_vartreat2[Birds, DNA]                               0.002   75175.0
# b_vartreat2[Birds, Habitat]                           0.002   61664.0
# b_vartreat2[Birds, Morphology]                        0.002   62044.0
# b_vartreat2[Birds, Neutral]                           0.002   68453.0
# b_vartreat2[Fish, DNA]                                0.002   63552.0
# b_vartreat2[Fish, Habitat]                            0.002   73042.0
# b_vartreat2[Fish, Morphology]                         0.002   70744.0
# b_vartreat2[Fish, Neutral]                            0.002   31612.0
# b_vartreat2[Fungi, DNA]                               0.002   75626.0
# b_vartreat2[Fungi, Habitat]                           0.002   72574.0
# b_vartreat2[Fungi, Morphology]                        0.002   69963.0
# b_vartreat2[Fungi, Neutral]                           0.002   57315.0
# b_vartreat2[Insects, DNA]                             0.001   60734.0
# b_vartreat2[Insects, Habitat]                         0.002   26895.0
# b_vartreat2[Insects, Morphology]                      0.001   65720.0
# b_vartreat2[Insects, Neutral]                         0.001   51670.0
# b_vartreat2[Mammals, DNA]                             0.002   74705.0
# b_vartreat2[Mammals, Habitat]                         0.002   69802.0
# b_vartreat2[Mammals, Morphology]                      0.001   57866.0
# b_vartreat2[Mammals, Neutral]                         0.001   71020.0
# b_vartreat2[Molluscs, DNA]                            0.002   65747.0
# b_vartreat2[Molluscs, Habitat]                        0.002   72647.0
# b_vartreat2[Molluscs, Morphology]                     0.002   76507.0
# b_vartreat2[Molluscs, Neutral]                        0.002   72679.0
# b_vartreat2[Non-insect Arthropods, DNA]               0.002   33054.0
# b_vartreat2[Non-insect Arthropods, Habitat]           0.001   69512.0
# b_vartreat2[Non-insect Arthropods, Morphology]        0.001   64479.0
# b_vartreat2[Non-insect Arthropods, Neutral]           0.001   46337.0
# b_vartreat2[Non-vertebrate Deuterostomes, DNA]        0.002   74587.0
# b_vartreat2[Non-vertebrate Deuterostomes, Habitat]    0.002   63157.0
# b_vartreat2[Non-vertebrate Deuterostomes, Morph...    0.002   72340.0
# b_vartreat2[Non-vertebrate Deuterostomes, Neutral]    0.002   69807.0
# b_vartreat2[Plants, DNA]                              0.002   63771.0
# b_vartreat2[Plants, Habitat]                          0.001   51670.0
# b_vartreat2[Plants, Morphology]                       0.001   31166.0
# b_vartreat2[Plants, Neutral]                          0.001   67503.0
# b_vartreat2[Prokaryotes, DNA]                         0.002   73793.0
# b_vartreat2[Prokaryotes, Habitat]                     0.002   66630.0
# b_vartreat2[Prokaryotes, Morphology]                  0.002   76194.0
# b_vartreat2[Prokaryotes, Neutral]                     0.002   78668.0
# b_vartreat2[Protists (non-algae), DNA]                0.002   72864.0
# b_vartreat2[Protists (non-algae), Habitat]            0.002   71943.0
# b_vartreat2[Protists (non-algae), Morphology]         0.002   73059.0
# b_vartreat2[Protists (non-algae), Neutral]            0.002   65062.0
# b_vartreat2[Remaining invertebrates, DNA]             0.002   56456.0
# b_vartreat2[Remaining invertebrates, Habitat]         0.002   70793.0
# b_vartreat2[Remaining invertebrates, Morphology]      0.001   71697.0
# b_vartreat2[Remaining invertebrates, Neutral]         0.001   54489.0
# b_vartreat2[Reptiles and Amphibia, DNA]               0.002   50830.0
# b_vartreat2[Reptiles and Amphibia, Habitat]           0.002   69223.0
# b_vartreat2[Reptiles and Amphibia, Morphology]        0.002   42290.0
# b_vartreat2[Reptiles and Amphibia, Neutral]           0.001   69890.0
#
#                                                     ess_tail  r_hat
# b_vartreat2[Algae, DNA]                              30307.0    1.0
# b_vartreat2[Algae, Habitat]                          30082.0    1.0
# b_vartreat2[Algae, Morphology]                       29604.0    1.0
# b_vartreat2[Algae, Neutral]                          30252.0    1.0
# b_vartreat2[Birds, DNA]                              26489.0    1.0
# b_vartreat2[Birds, Habitat]                          30181.0    1.0
# b_vartreat2[Birds, Morphology]                       30016.0    1.0
# b_vartreat2[Birds, Neutral]                          33449.0    1.0
# b_vartreat2[Fish, DNA]                               29811.0    1.0
# b_vartreat2[Fish, Habitat]                           30766.0    1.0
# b_vartreat2[Fish, Morphology]                        32509.0    1.0
# b_vartreat2[Fish, Neutral]                           32175.0    1.0
# b_vartreat2[Fungi, DNA]                              30924.0    1.0
# b_vartreat2[Fungi, Habitat]                          30930.0    1.0
# b_vartreat2[Fungi, Morphology]                       31070.0    1.0
# b_vartreat2[Fungi, Neutral]                          30035.0    1.0
# b_vartreat2[Insects, DNA]                            30957.0    1.0
# b_vartreat2[Insects, Habitat]                        32455.0    1.0
# b_vartreat2[Insects, Morphology]                     34750.0    1.0
# b_vartreat2[Insects, Neutral]                        33880.0    1.0
# b_vartreat2[Mammals, DNA]                            30845.0    1.0
# b_vartreat2[Mammals, Habitat]                        31514.0    1.0
# b_vartreat2[Mammals, Morphology]                     32103.0    1.0
# b_vartreat2[Mammals, Neutral]                        32908.0    1.0
# b_vartreat2[Molluscs, DNA]                           31419.0    1.0
# b_vartreat2[Molluscs, Habitat]                       30290.0    1.0
# b_vartreat2[Molluscs, Morphology]                    30578.0    1.0
# b_vartreat2[Molluscs, Neutral]                       31517.0    1.0
# b_vartreat2[Non-insect Arthropods, DNA]              31794.0    1.0
# b_vartreat2[Non-insect Arthropods, Habitat]          31627.0    1.0
# b_vartreat2[Non-insect Arthropods, Morphology]       32229.0    1.0
# b_vartreat2[Non-insect Arthropods, Neutral]          31109.0    1.0
# b_vartreat2[Non-vertebrate Deuterostomes, DNA]       29656.0    1.0
# b_vartreat2[Non-vertebrate Deuterostomes, Habitat]   28712.0    1.0
# b_vartreat2[Non-vertebrate Deuterostomes, Morph...   29729.0    1.0
# b_vartreat2[Non-vertebrate Deuterostomes, Neutral]   29183.0    1.0
# b_vartreat2[Plants, DNA]                             30817.0    1.0
# b_vartreat2[Plants, Habitat]                         32235.0    1.0
# b_vartreat2[Plants, Morphology]                      31499.0    1.0
# b_vartreat2[Plants, Neutral]                         33282.0    1.0
# b_vartreat2[Prokaryotes, DNA]                        28870.0    1.0
# b_vartreat2[Prokaryotes, Habitat]                    29579.0    1.0
# b_vartreat2[Prokaryotes, Morphology]                 30671.0    1.0
# b_vartreat2[Prokaryotes, Neutral]                    29188.0    1.0
# b_vartreat2[Protists (non-algae), DNA]               31213.0    1.0
# b_vartreat2[Protists (non-algae), Habitat]           31483.0    1.0
# b_vartreat2[Protists (non-algae), Morphology]        31573.0    1.0
# b_vartreat2[Protists (non-algae), Neutral]           29717.0    1.0
# b_vartreat2[Remaining invertebrates, DNA]            31972.0    1.0
# b_vartreat2[Remaining invertebrates, Habitat]        32105.0    1.0
# b_vartreat2[Remaining invertebrates, Morphology]     31487.0    1.0
# b_vartreat2[Remaining invertebrates, Neutral]        32478.0    1.0
# b_vartreat2[Reptiles and Amphibia, DNA]              32767.0    1.0
# b_vartreat2[Reptiles and Amphibia, Habitat]          30782.0    1.0
# b_vartreat2[Reptiles and Amphibia, Morphology]       30972.0    1.0
# b_vartreat2[Reptiles and Amphibia, Neutral]          31122.0    1.0

# %%
fig, axs = plt.subplots(ncols = 4, figsize = (18,5))

for ax,i in zip(axs.flat, ['DNA', 'Habitat', 'Morphology', 'Neutral']):
    a = (tracem7.posterior['a_gen'] + 
        tracem7.posterior['a1'].mean(dim = 'sc_n')+
        tracem7.posterior['b_treat'].loc[:,:,i] +
        (tracem7.posterior['a3'].mean(dim = 'c_n')) +
       tracem7.posterior['b_vartreat1'].loc[:,:,:,i].mean(dim = 'c_n')+
        tracem7.posterior['a2'].mean(dim = 'tax_n')+
        tracem7.posterior['b_vartreat2'].loc[:,:,:,i].mean(dim = 'tax_n'))
    az.plot_posterior(expit(a), hdi_prob = 0.8,ax=ax)
    ax.set_title(i)

# %%
#priors vs posteriors
fig, axs = plt.subplots(3,3, figsize = (20,9))

for ax, para in zip(axs.flat, ['a1','a_gen','b_treat','a1_sigma','b_vartreat2','b_vartreat1','a3', 'a2', 'a2_sigma']):
    if len(pr7.prior[para].shape) == 3:
        az.plot_posterior(pr7.prior[para][:,:,0], hdi_prob = 'hide',point_estimate = None, ax=ax)
        az.plot_posterior(tracem7.posterior[para][:,:,0], point_estimate = None,hdi_prob = 'hide', color = 'red', ax=ax)
    elif len(pr7.prior[para].shape) == 2:
        az.plot_posterior(pr7.prior[para], hdi_prob = 'hide',point_estimate = None,ax=ax)
        az.plot_posterior(tracem7.posterior[para],hdi_prob ='hide', point_estimate = None,color = 'red',ax=ax)
    else:
        az.plot_posterior(pr7.prior[para][:,:,1,0], hdi_prob = 'hide',point_estimate = None,ax=ax)
        az.plot_posterior(tracem7.posterior[para][:,:,1,0], hdi_prob = 'hide',point_estimate = None,color = 'red',ax=ax)
        
plt.suptitle('priors (blue) vs posteriors for selected parameters', fontsize = 20) 

fig.tight_layout()

# %%
# prior vs posterior for the treatments


fig, axs = plt.subplots(1,3, figsize = (20,6), sharex = True)

for ax, i in zip(axs.flat, range(3)):
    az.plot_posterior(pr7.prior['b_treat'][:,:,i], point_estimate = None, hdi_prob = 'hide',ax=ax)
    az.plot_posterior(tracem7.posterior['b_treat'][:,:,i], color = 'red',ax=ax)

# %% [markdown]
# As it happens, the coefficients for tax and cont do give an idea of their direct influence according to our dag (i.e. without their influence through species concept)

# %%
fig, ax = plt.subplots(ncols = 2, figsize = (18,6))

az.plot_forest(tracem7, var_names = ['b_vartreat1'], coords ={'t_n':['DNA','Morphology','Habitat']}, combined = True, ax = ax[0])
az.plot_forest(tracem7, 
               var_names = ['b_vartreat2'], 
               coords = {'t_n':['Morphology','Habitat'], 'tax_n': [ 'Birds', 'Fish', 'Insects', 'Mammals',
                                                                   'Non-insect Arthropods','Plants', 
                                                                   'Remaining invertebrates','Reptiles and Amphibia']}, 
               combined = True, ax = ax[1])
fig.tight_layout()

# %% [markdown]
# ## Causal effect of treatment

# %%
# plot difference in coefficients

fig, ax = plt.subplots(figsize = (10,4))
NEUT_result = tracem7.posterior['b_treat'].loc[:,:,'Neutral']

difs = []
for i in tracem7.posterior['t_n'].values[:-1]:
    sns.kdeplot(np.ravel(tracem7.posterior['b_treat'].loc[:,:,i] - NEUT_result),  ax=ax)
    
ax.set_title('Difference in coefficient between Neutral and other treatments')
ax.legend(list(tracem7.posterior['t_n'].values[:-1]))
plt.show()

# %%
# create new data for T
new_t_data = {}

for i in range(4):
    new_t_data[f't{i}'] = np.repeat(i, len(df))

ppc = {}

with m7:
    for i in range(4):
        pm.set_data(
            {
                "T":new_t_data[f't{i}']
            }
        )
        ppct = pm.sample_posterior_predictive(tracem7, progressbar = False)
        ppc[f't{i}'] = ppct
# Out:
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]

# %%
Morph = az.extract(ppc[f't{2}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)

colors = ['red','blue','green','orange']

fig, ax = plt.subplots(nrows = 2, figsize = (18,10))

lst = list(ppc.values())
for i in range(4):
    a = az.extract(ppc[f't{i}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)

    sns.kdeplot(np.array(a), color = colors[i],ax=ax[0] )
    
ax[0].set_title('Posterior predictive proportion of Agree for the treatments', fontsize = 25)
ax[0].legend(['DNA', 'Habitat', 'Morphology', 'Neutral'])

for i in range(2):
    a = az.extract(ppc[f't{i}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)
    sns.kdeplot(np.array(a) - Morph, color = colors[i],ax=ax[1] )

    
ax[1].set_title('Difference in proportion of agree between Morphology and Habitat/DNA', fontsize = 25)
ax[1].legend(['DNA', 'Habitat'])

plt.show()

# %% [markdown]
# ## Causal effect of SC on 'Agree'

# %%
# plot difference in coefficients

fig, ax = plt.subplots(figsize = (10,4))
BSC_result = tracem7.posterior['a1'].loc[:,:,'BSC']

difs = []
for i in tracem7.posterior['sc_n'].values[1:]:
    sns.kdeplot(np.ravel(tracem7.posterior['a1'].loc[:,:,i] - BSC_result),  ax=ax)
    
ax.set_title('Difference in coefficient between BSC and other concepts')
ax.legend(list(tracem7.posterior['sc_n'].values[1:]))
plt.show()

# %%
# posterior predictive: resample with full sample subscribing to each of the concepts, and compare resulting agree

# create new data for SC

new_sc_data = {f'sc{i}': np.repeat(i, len(df)) for i in range(6)}

# sample 6x ppc setting full sample for one concept in turn

ppcs = {}
with m7:
    for i in list(range((6))):
        pm.set_data({"S":new_sc_data[f'sc{i}']})
        ppc = pm.sample_posterior_predictive(tracem7, progressbar = False)
        ppcs[f'sc{i}'] = ppc

# plot differences between BSC and the rest

colors = ['EMPTY','yellow','blue','green','red','black']
BSC = az.extract(ppcs[f'sc{0}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)

fig, ax = plt.subplots(figsize = (20,5))

lst = list(ppcs.values())
for i in list(range(1,6,1)):
    agree_prop = az.extract(ppcs[f'sc{i}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)
    sns.kdeplot(np.array(agree_prop - BSC), color = colors[i],ax=ax )
                    
ax.set_title('PPC difference in "Agree" between BSC and other concepts', fontsize = 25)
ax.legend(['ESC', 'GCSP', 'PSCdia', 'PSCmono', 'other'])
ax.axvline(0, color = 'grey')
# Out:
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]

# %% [markdown]
# ## Does treatment effect vary between continents?

# %%
az.plot_forest(tracem7, 
               var_names = ['b_vartreat1', 'a3'],
              combined = True)
# Out:
# array([<Axes: title={'center': '94.0% HDI'}>], dtype=object)

# %%
# ppc: new data for c by treatment

new_c_data = {f'c{i}': np.repeat(i, len(df)) for i in range(2)}

ppcs_DNA = {}
ppcs_Morph = {}
ppcs_HAB = {}



with m7:
    for i in list(range((2))):
        pm.set_data(
            {
                "C":new_c_data[f'c{i}'],
                "T": np.repeat(0, len(df))
            }
        )
        ppcsc = pm.sample_posterior_predictive(tracem7, progressbar = False)
        ppcs_DNA[f'c{i}'] = ppcsc
        
        pm.set_data(
            {
                "S":new_c_data[f'c{i}'],
                "T": np.repeat(2, len(df))
            }
        )
        ppcsc = pm.sample_posterior_predictive(tracem7, progressbar = False)
        ppcs_Morph[f'c{i}'] = ppcsc
        
        pm.set_data(
            {
                "S":new_c_data[f'c{i}'],
                "T": np.repeat(1, len(df))
            }
        )
        ppcsc = pm.sample_posterior_predictive(tracem7, progressbar = False)
        ppcs_HAB[f'c{i}'] = ppcsc
# Out:
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]

# %%
# plot 
# DNA = az.extract(ppcs_DNA[f'sc{0}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)
# Morph = az.extract(ppcs_Morph[f'sc{0}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)

colors = ['orange','yellow','blue','green','red','black']

fig, ax = plt.subplots(figsize = (18,5))

for i in [ppcs_DNA, ppcs_Morph, ppcs_HAB]:
    li = az.extract(i[f'c{1}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)
    hi = az.extract(i[f'c{0}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)
    dif = li - hi

    sns.kdeplot(np.array(dif),ax=ax )
    
ax.set_title('Difference between low income and high income in agree for all treatments', fontsize = 20)
ax.legend(['DNA','Morphology','Habitat'])


fig.tight_layout()

# %% [markdown]
# ## Influence treatment vs influence species concepts

# %%
# create new data for T
new_t_data = {}

for i in range(4):
    new_t_data[f't{i}'] = np.repeat(i, len(df))

ppc = {}

with m7:
    for i in range(4):
        pm.set_data(
            {
                "T":new_t_data[f't{i}']
            }
        )
        ppct = pm.sample_posterior_predictive(tracem7, progressbar = False)
        ppc[f't{i}'] = ppct
# Out:
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]
# Sampling: [agree]

# %%
# compare concept effect and treatment effect
Neutral = az.extract(ppc[f't{1}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)

blues = [ 'blue',
 'deepskyblue',
 'lightsteelblue',
 'steelblue',
 'powderblue',
 'royalblue',
 ]
reds= ['red','coral']

fig, ax = plt.subplots(figsize = (18,5))

Morph = az.extract(ppc[f't{2}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)


for i in range(2):
    a = az.extract(ppc[f't{i}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)
    sns.kdeplot(np.array(a) - Morph, color = reds[i],ax=ax)



# plot differences between BSC and the rest

BSC = az.extract(ppcs[f'sc{0}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)


for i in range(1,6,1):
    agree_prop = az.extract(ppcs[f'sc{i}'].posterior_predictive['agree'])['agree'].values.sum(axis = 0) / len(df)
    sns.kdeplot(np.array(agree_prop - BSC), color = blues[i],ax=ax )
                    
ax.legend(['DNA','Habitat','ESC', 'GCSP', 'PSCdia', 'PSCmono', 'other'])
ax.set_title('PPC effect of species concepts (blue) and treatments(red)')
plt.show()
